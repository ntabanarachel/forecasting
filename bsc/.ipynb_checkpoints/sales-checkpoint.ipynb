# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading all sheets
sales = pd.read_excel('./datasets/Sales_project.xlsx')
customers = pd.read_excel('./datasets/Sales_project.xlsx', 'Customers Sheet')
sites = pd.read_excel('./datasets/Sales_project.xlsx', 'Site Location sheet')
products = pd.read_excel('./datasets/Sales_project.xlsx', 'Products_Sheet')
teams = pd.read_excel('./datasets/Sales_project.xlsx', 'Sales Team Sheet')

# %%
sales.head(30)
# Out:
#     OrderNumber  OrderDate CurrencyCode  _SalesAM_ID  _CustomerID  _SiteID  \
# 0   SO - 000101 2018-05-31          RWF            6           15      259
# 1   SO - 000102 2018-05-31          RWF           14           20      196
# 2   SO - 000103 2018-05-31          RWF           21           16      213
# 3   SO - 000104 2018-05-31          RWF           28           48      107
# 4   SO - 000105 2018-05-31          RWF           22           49      111
# 5   SO - 000106 2018-05-31          RWF           12           21      285
# 6   SO - 000107 2018-05-31          RWF           10           14        6
# 7   SO - 000108 2018-05-31          RWF            6            9      280
# 8   SO - 000109 2018-06-01          RWF            4            9      299
# 9   SO - 000110 2018-06-01          RWF           10           33      261
# 10  SO - 000111 2018-06-01          RWF           23           21       17
# 11  SO - 000112 2018-06-01          RWF           10           21      152
# 12  SO - 000113 2018-06-01          RWF            4           36      317
# 13  SO - 000114 2018-06-01          RWF            8           17      291
# 14  SO - 000115 2018-06-01          RWF            9           32      138
# 15  SO - 000116 2018-06-01          RWF            5           11      354
# 16  SO - 000117 2018-06-01          RWF            9           10      320
# 17  SO - 000118 2018-06-01          RWF            8           30       21
# 18  SO - 000119 2018-06-01          RWF            5            5      349
# 19  SO - 000120 2018-06-01          RWF           14           23      134
# 20  SO - 000121 2018-06-01          RWF           25           46      193
# 21  SO - 000122 2018-06-02          RWF            2           14      282
# 22  SO - 000123 2018-06-02          RWF            7           40       20
# 23  SO - 000124 2018-06-02          RWF           24           19      218
# 24  SO - 000125 2018-06-02          RWF            4           15      173
# 25  SO - 000126 2018-06-02          RWF           18           46      110
# 26  SO - 000127 2018-06-02          RWF            7           32      229
# 27  SO - 000128 2018-06-02          RWF            9           32      238
# 28  SO - 000129 2018-06-02          RWF           20           22       97
# 29  SO - 000130 2018-06-02          RWF            8            5      103
#
#     _ProductID  Order Quantity  Discount Applied  Unit Price  Unit Cost
# 0           12               5             0.075      1963.1   1001.181
# 1           27               3             0.075      3939.6   3348.660
# 2           16               1             0.050      1775.5    781.220
# 3           23               8             0.075      2324.9   1464.687
# 4           26               8             0.100      1822.4   1476.144
# 5            1               5             0.050      1038.5    446.555
# 6            5               4             0.150      1192.6    536.670
# 7           46               5             0.050      1815.7   1525.188
# 8           47               4             0.300      3879.3   2211.201
# 9           13               8             0.050      1956.4   1212.968
# 10          38               6             0.100       201.0    124.620
# 11          40               5             0.150      6277.9   2762.276
# 12          39               5             0.050      1051.9    641.659
# 13          32               6             0.150       254.6    216.410
# 14           6               6             0.150      3932.9   3146.320
# 15          25               3             0.050      1112.2    700.686
# 16           6               3             0.075      1239.5    904.835
# 17           3               4             0.100       984.9    393.960
# 18          20               4             0.100      5581.1   4130.014
# 19          24               4             0.050      3095.4   1795.332
# 20          33               4             0.400      2278.0   1754.060
# 21           1               7             0.075       991.6    654.456
# 22          35               2             0.200      3979.8   3064.446
# 23          15               3             0.400      1969.8    866.712
# 24          13               1             0.150       268.0    131.320
# 25          24               7             0.100       174.2     95.810
# 26          46               3             0.075      2988.2   2510.088
# 27          36               4             0.050      3999.9   2679.933
# 28          37               3             0.050      5976.4   2450.324
# 29          32               5             0.100      2901.1   2378.902

# %%
fig = (18,8)
plt.figure(figsize=fig)
heatmap = sns.heatmap(sales.corr(method='pearson'), annot=True, fmt='.1g', vmin=-1, vmax=1, center=0, cmap='inferno', linewidths=1, linecolor='Black')
heatmap.set_title('correlation heatmap between variables')
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, '_SalesAM_ID'),
#  Text(1.5, 0, '_CustomerID'),
#  Text(2.5, 0, '_SiteID'),
#  Text(3.5, 0, '_ProductID'),
#  Text(4.5, 0, 'Order Quantity'),
#  Text(5.5, 0, 'Discount Applied'),
#  Text(6.5, 0, 'Unit Price'),
#  Text(7.5, 0, 'Unit Cost')]

# %%
"unique unit cost", len(set(sales['Unit Cost'])),"unique unit price", len(set(sales['Unit Price'])),"unique order number", len(set(sales['OrderNumber']))
# Out:
# ('unique unit cost',
#  5581,
#  'unique unit price',
#  664,
#  'unique order number',
#  7991)

# %%
customers.head(10)
# Out:
#    _CustomerID Customer Names
# 0            1      Avon Corp
# 1            2      WakeFern
# 2            3   Elorac, Corp
# 3            4      ETUDE Ltd
# 4            5   Procter Corp
# 5            6  PEDIFIX, Corp
# 6            7        New Ltd
# 7            8   Medsep Group
# 8            9            Ei
# 9           10       21st Ltd

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderNumber       7991 non-null   object
#  1   OrderDate         7991 non-null   datetime64[ns]
#  2   CurrencyCode      7991 non-null   object
#  3   _SalesAM_ID       7991 non-null   int64
#  4   _CustomerID       7991 non-null   int64
#  5   _SiteID           7991 non-null   int64
#  6   _ProductID        7991 non-null   int64
#  7   Order Quantity    7991 non-null   int64
#  8   Discount Applied  7991 non-null   float64
#  9   Unit Price        7991 non-null   float64
#  10  Unit Cost         7991 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(2)
# memory usage: 686.9+ KB

# %%
products.head()
# Out:
#   _ProductID         Product Name             Item/Service Description  \
# 0      I0016  4G LTE connectivity                  4G GO SMART 1GB/DAY
# 1      I0017  4G LTE connectivity                  4G MUP  1GB/DAY GOV
# 2      I0018  4G LTE connectivity               4G GO PLATINUM 4GB/DAY
# 3      I0020  4G LTE connectivity                   4G UNLIMITED 100GB
# 4      I0021  4G LTE connectivity  4G ONE NETWORK 3MBPS + INSTALLATION
#
#   Bandwidth
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
products_index = [a for a in range(len(products))]
products['products_index'] = products_index
products.head()
# Out:
#                    Product Name             Item/Service Description  \
# _ProductID
# I0016       4G LTE connectivity                  4G GO SMART 1GB/DAY
# I0017       4G LTE connectivity                  4G MUP  1GB/DAY GOV
# I0018       4G LTE connectivity               4G GO PLATINUM 4GB/DAY
# I0020       4G LTE connectivity                   4G UNLIMITED 100GB
# I0021       4G LTE connectivity  4G ONE NETWORK 3MBPS + INSTALLATION
#
#            Bandwidth  products_index
# _ProductID
# I0016              0               0
# I0017              0               1
# I0018              0               2
# I0020              0               3
# I0021              0               4

# %%
data = sales.join(customers.set_index('_CustomerID'), on='_CustomerID').join(sites.set_index('_SiteID'), on='_SiteID').join(products.set_index('products_index'), on='_ProductID')

# %%
data.isnull().sum()
# Out:
# OrderNumber                   0
# OrderDate                     0
# CurrencyCode                  0
# _SalesAM_ID                   0
# _CustomerID                   0
# _SiteID                       0
# _ProductID                    0
# Order Quantity                0
# Discount Applied              0
# Unit Price                    0
# Unit Cost                     0
# Customer Names                0
# SIte Name                     0
# District                      0
# Product Name                152
# Item/Service Description    152
# Bandwidth                   152
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# _CustomerID       0
# Customer Names    0
# dtype: int64

# %%
data.head()
# Out:
#    OrderNumber  OrderDate CurrencyCode  _SalesAM_ID  _CustomerID  _SiteID  \
# 0  SO - 000101 2018-05-31          RWF            6           15      259
# 1  SO - 000102 2018-05-31          RWF           14           20      196
# 2  SO - 000103 2018-05-31          RWF           21           16      213
# 3  SO - 000104 2018-05-31          RWF           28           48      107
# 4  SO - 000105 2018-05-31          RWF           22           49      111
#
#    _ProductID  Order Quantity  Discount Applied  Unit Price  Unit Cost  \
# 0          12               5             0.075      1963.1   1001.181
# 1          27               3             0.075      3939.6   3348.660
# 2          16               1             0.050      1775.5    781.220
# 3          23               8             0.075      2324.9   1464.687
# 4          26               8             0.100      1822.4   1476.144
#
#   Customer Names SIte Name   District                Product Name  \
# 0  Rochester Ltd         Y   Kicukiro    Fiber Broadband Internet
# 1    Pacific Ltd         N  Rwamagana  Video Conferencing Service
# 2      3LAB, Ltd         E    Gakenke    Fiber Broadband Internet
# 3   Fenwal, Corp         C     Gasabo                         MSS
# 4          Bare          G     Gasabo                        VOIP
#
#   Item/Service Description Bandwidth
# 0     FIBER INTERNET 1MBPS         1
# 1         VIDEO CONFERENCE         0
# 2    FIBER INTERNET 10MBPS        10
# 3                 MSS GOLD         0
# 4        VOIP PHONES 21-40         0

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
# dataset = enc.fit_transform(data[['OrderDate','CurrencyCode','SIte Name','District','Product Name', 'Item/Service Description']])
# dataset['CurrencyCode'] = enc.fit_transform(dataset['CurrencyCode'])
dataset['SIte Name'] = enc.fit_transform(dataset['SIte Name'])
dataset['District'] = enc.fit_transform(dataset['District'])
dataset['Product Name'] = enc.fit_transform(dataset['Product Name'])
dataset['Item/Service Description'] = enc.fit_transform(dataset['Item/Service Description'])
dataset['Customer Names'] = enc.fit_transform(dataset['Customer Names'])
dataset['OrderDate'] = enc.fit_transform(dataset['OrderDate'])

# %%
dataset = pd.DataFrame(data, columns=data.columns)
dataset
# Out:
#        OrderNumber  OrderDate  CurrencyCode  _SalesAM_ID  _CustomerID  \
# 0      SO - 000101          0             0            6           15
# 1      SO - 000102          0             0           14           20
# 2      SO - 000103          0             0           21           16
# 3      SO - 000104          0             0           28           48
# 4      SO - 000105          0             0           22           49
# ...            ...        ...           ...          ...          ...
# 7986  SO - 0008087        944             0            9           41
# 7987  SO - 0008088        944             0           14           29
# 7988  SO - 0008089        944             0           14           32
# 7989  SO - 0008090        944             0           20           42
# 7990  SO - 0008091        944             0            6           41
#
#       _SiteID  _ProductID  Order Quantity  Discount Applied  Unit Price  \
# 0         259          12               5             0.075      1963.1
# 1         196          27               3             0.075      3939.6
# 2         213          16               1             0.050      1775.5
# 3         107          23               8             0.075      2324.9
# 4         111          26               8             0.100      1822.4
# ...       ...         ...             ...               ...         ...
# 7986      339          29               1             0.075       234.5
# 7987      202           3               6             0.050      3202.6
# 7988      241          35               5             0.200      3825.7
# 7989      112          36               8             0.100      1072.0
# 7990      237          43               5             0.075      2211.0
#
#       Unit Cost  Customer Names  SIte Name  District  Product Name  \
# 0      1001.181              38         24        18             5
# 1      3348.660              33         13        42            11
# 2       781.220               1          4         5             5
# 3      1464.687              18          2         6             8
# 4      1476.144               8          6         6             9
# ...         ...             ...        ...       ...           ...
# 7986    121.940              47          0        22             6
# 7987   1921.560               4         19         9             0
# 7988   2792.761              28          6         8             1
# 7989    804.000              20          7        18             7
# 7990   1370.820              47          2         6             5
#
#       Item/Service Description Bandwidth
# 0                           21         1
# 1                           37         0
# 2                           18        10
# 3                           33         0
# 4                           39         0
# ...                        ...       ...
# 7986                        42         5
# 7987                         6         0
# 7988                        11         0
# 7989                        36         0
# 7990                        32         -
#
# [7991 rows x 17 columns]

# %%
fig = (18,8)
plt.figure(figsize=fig)
heatmap = sns.heatmap(dataset.corr(method='pearson'), annot=True, fmt='.1g', vmin=-1, vmax=1, center=0, cmap='inferno', linewidths=1, linecolor='Black')
heatmap.set_title('correlation heatmap between variables')
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 0, 'OrderDate'),
#  Text(1.5, 0, 'CurrencyCode'),
#  Text(2.5, 0, '_SalesAM_ID'),
#  Text(3.5, 0, '_CustomerID'),
#  Text(4.5, 0, '_SiteID'),
#  Text(5.5, 0, '_ProductID'),
#  Text(6.5, 0, 'Order Quantity'),
#  Text(7.5, 0, 'Discount Applied'),
#  Text(8.5, 0, 'Unit Price'),
#  Text(9.5, 0, 'Unit Cost'),
#  Text(10.5, 0, 'Customer Names'),
#  Text(11.5, 0, 'SIte Name'),
#  Text(12.5, 0, 'District'),
#  Text(13.5, 0, 'Product Name'),
#  Text(14.5, 0, 'Item/Service Description')]
